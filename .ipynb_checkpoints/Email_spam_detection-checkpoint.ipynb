# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("spam_ham_dataset.csv")

# %%
df.tail(5)
# Out:
#       Unnamed: 0 label                                               text  \
# 5166        1518   ham  Subject: put the 10 on the ft\r\nthe transport...
# 5167         404   ham  Subject: 3 / 4 / 2000 and following noms\r\nhp...
# 5168        2933   ham  Subject: calpine daily gas nomination\r\n>\r\n...
# 5169        1409   ham  Subject: industrial worksheets for august 2000...
# 5170        4807  spam  Subject: important online banking alert\r\ndea...
#
#       label_num
# 5166          0
# 5167          0
# 5168          0
# 5169          0
# 5170          1

# %%
df.shape
# Out:
# (5171, 4)

# %% [markdown]
# ## Data cleaning

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5171 entries, 0 to 5170
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5171 non-null   int64
#  1   label       5171 non-null   str
#  2   text        5171 non-null   str
#  3   label_num   5171 non-null   int64
# dtypes: int64(2), str(2)
# memory usage: 5.3 MB

# %%
# drop unnamed column
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.sample(5)
# Out:
#      label                                               text  label_num
# 1508  spam                              Subject: re [ 8 ]\r\n          1
# 1445   ham  Subject: mobil beaumont - may 2001\r\ndaren ,\...          0
# 54     ham  Subject: re : pg & e texas meeting\r\nrecap of...          0
# 1901   ham  Subject: november prelim wellhead production -...          0
# 5065   ham  Subject: tenaska marketing ventures - 04 / 01 ...          0

# %%
# renaming the columns
df.rename(columns={'label':'Type','label_num':'Type_no'},inplace=True)
df.sample()
# Out:
#      Type                                               text  Type_no
# 3198  ham  Subject: ua 4 - 1998\r\ndaren :\r\nwe are curr...        0

# %%
# their is no need for label encoder but if was required
# form sklearn.preprocessing import LabelEncoder
#encoder=LabelEncoder()
#df['type']=encoder.fit_trasnform(df['type'])

# %%
# missing values
df.isnull().sum()
# Out:
# Type       0
# text       0
# Type_no    0
# dtype: int64

# %%
#check for duplicate values
df.duplicated().sum()
# Out:
# np.int64(178)

# %%
df = df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (4993, 3)

# %% [markdown]
# ## EDA

# %%
df['Type_no'].value_counts()
# Out:
# Type_no
# 0    3531
# 1    1462
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['Type_no'].value_counts(), labels=['ham','spam'], autopct= "%0.2f")
plt.show()

# %%
# data is imbalanced

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (3.10.2)
# Requirement already satisfied: defusedxml in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (from nltk) (0.7.1)
# Requirement already satisfied: click in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (from nltk) (8.3.2)
# Requirement already satisfied: joblib in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (from nltk) (2026.4.4)
# Requirement already satisfied: tqdm in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\abhay\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# characters in mail
df['num_characters']=df['text'].apply(len)
df.head()
# Out:
#    Type                                               text  Type_no  \
# 0   ham  Subject: enron methanol ; meter # : 988291\r\n...        0
# 1   ham  Subject: hpl nom for january 9 , 2001\r\n( see...        0
# 2   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...        0
# 3  spam  Subject: photoshop , windows , office . cheap ...        1
# 4   ham  Subject: re : indian springs\r\nthis deal is t...        0
#
#    num_characters
# 0             327
# 1              97
# 2            2524
# 3             414
# 4             336

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\abhay\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# words in mail
df['num_words']=df['text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
# sentence in mail
df['num_sentences']=df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    Type                                               text  Type_no  \
# 0   ham  Subject: enron methanol ; meter # : 988291\r\n...        0
# 1   ham  Subject: hpl nom for january 9 , 2001\r\n( see...        0
# 2   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...        0
# 3  spam  Subject: photoshop , windows , office . cheap ...        1
# 4   ham  Subject: re : indian springs\r\nthis deal is t...        0
#
#    num_characters  num_words  num_sentences
# 0             327         68              3
# 1              97         24              3
# 2            2524        551             24
# 3             414         49              3
# 4             336         71              3

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4993.000000  4993.000000    4993.000000
# mean      1069.426397   233.678149      13.386942
# std       1547.863387   340.702932      27.959959
# min         11.000000     2.000000       1.000000
# 25%        256.000000    55.000000       4.000000
# 50%        557.000000   125.000000       7.000000
# 75%       1262.000000   288.000000      15.000000
# max      32258.000000  8863.000000    1204.000000

# %%
# ham
df[df['Type_no'] == 0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     3531.000000  3531.000000    3531.000000
# mean       994.939394   230.516001      11.662419
# std       1402.785831   337.018933      25.330035
# min         18.000000     3.000000       1.000000
# 25%        241.000000    53.000000       4.000000
# 50%        538.000000   128.000000       7.000000
# 75%       1253.500000   298.500000      13.500000
# max      32258.000000  8863.000000    1204.000000

# %%
# spam
df[df['Type_no'] == 1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     1462.000000  1462.000000    1462.000000
# mean      1249.326265   241.315321      17.551984
# std       1840.112883   349.439381      33.111447
# min         11.000000     2.000000       1.000000
# 25%        304.250000    60.000000       4.000000
# 50%        589.000000   119.500000       9.000000
# 75%       1305.000000   252.750000      19.000000
# max      22073.000000  3963.000000     693.000000

# %%
# !pip install seaborn
import seaborn as sns
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.4.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.0.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\abhay\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
plt.figure(figsize=(15,9))
sns.histplot(df[df['Type_no']==0]['num_characters'])
sns.histplot(df[df['Type_no']==1]['num_characters'],color = 'red')
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
plt.figure(figsize=(15,9))
sns.histplot(df[df['Type_no']==0]['num_words'])
sns.histplot(df[df['Type_no']==1]['num_words'],color = 'red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df,hue='Type_no')

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Data Preprocessing
# * lower case
# * tokenization
# * removing special character
# * removing stop word
# * stemming/lemitization

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\abhay\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('loving')
# Out:
# 'love'

# %%
def transform_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)

    y=[]
    for i in text:
        if i.isalnum():
            y.append(i)
    text = y[:]
    y.clear()# y need to be cloned else if y cleared then text also get cleared

    
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)

    text = y[:]
    y.clear()

    for i in text:
        y.append(ps.stem(i))
    
    return " ".join(y)

# %%
df['trasnformed_text'] = df['text'].apply(transform_text)

# %%
df = df.rename(columns={'trasnformed_text':'transformed_text'})

# %%
df.head()

# %%
from wordcloud import WordCloud
wc = WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
spam_wc = wc.generate(df[df['Type_no'] == 1]['transformed_text'].str.cat(sep=" "))

# %%
plt.imshow(spam_wc)

# %%
ham_wc = wc.generate(df[df['Type_no'] == 0]['transformed_text'].str.cat(sep=" "))
plt.imshow(ham_wc)

# %%
#finding most common word
spam_corpus = []
for msg in df[df['Type_no'] == 1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)

# %%
from collections import Counter
df_top5 = pd.DataFrame(Counter(spam_corpus).most_common(30))
sns.barplot(x=df_top5[0], y=df_top5[1])
plt.xticks(rotation='vertical')

# %%
#finding most common word
ham_corpus = []
for msg in df[df['Type_no'] == 0]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)
len(ham_corpus)

# %%
df_top5 = pd.DataFrame(Counter(ham_corpus).most_common(30))
sns.barplot(x=df_top5[1], y=df_top5[0])
plt.xticks(rotation='vertical')

# %%
#first with naive basse since it perform well on text data
#text into words= bag of words(frequent word columns),tfidf,word to vector

# %% [markdown]
# ## Model building

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer() #CountVectorizer=bag of word
tfidf = TfidfVectorizer()

# %%
X = cv.fit_transform(df['transformed_text']).toarray()
X1 = tfidf.fit_transform(df['transformed_text']).toarray()

# %%
X.shape
X1.shape

# %%
y = df['Type_no'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)
X1_train,X1_test,y_train,y_test = train_test_split(X1,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))

# %%
gnb.fit(X1_train,y_train)
y_pred1_1 = gnb.predict(X1_test)
print(accuracy_score(y_test,y_pred1_1))
print(confusion_matrix(y_test,y_pred1_1))
print(precision_score(y_test,y_pred1_1))

# %%
mnb.fit(X_train,y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))

# %%
mnb.fit(X1_train,y_train)
y_pred2_1 = mnb.predict(X1_test)
print(accuracy_score(y_test,y_pred2_1))
print(confusion_matrix(y_test,y_pred2_1))
print(precision_score(y_test,y_pred2_1))

# %%
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))

# %%
bnb.fit(X1_train,y_train)
y_pred3_1 = bnb.predict(X1_test)
print(accuracy_score(y_test,y_pred3_1))
print(confusion_matrix(y_test,y_pred3_1))
print(precision_score(y_test,y_pred3_1))

# %%
#tfidf  mnb

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
svc = SVC(kernel ='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver = 'liblinear', penalty ='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state = 2)
abc = AdaBoostClassifier(n_estimators=50, random_state = 2)
bc = BaggingClassifier(n_estimators=50, random_state = 2)
etc = ExtraTreesClassifier(n_estimators=50, random_state = 2)
gbc = GradientBoostingClassifier(n_estimators=50, random_state = 2)
xgb = XGBClassifier(n_estimators=50, random_state = 2)
#basic hyperparameter tunning

# %%
clfs = {
    'SVC' : svc,
    'KN' : knc,
    'NB' : mnb,
    'DT' : dtc,
    'LR' : lrc,
    'RF' : rfc,
    'AdaBoost' : abc,
    'Bgc' : bc,
    'ETC' : etc,
    'GBDT' : gbc,
    'xgb' : xgb
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)

    return accuracy,precision

# %%
train_classifier(svc,X_train,y_train,X_test,y_test) #example

# %%
accuracy_scores = []
precision_scores = []
for name,clf in clfs.items():
    current_accuracy,current_precision = train_classifier(clf,X_train,y_train,X_test,y_test)

    print("for ",name)
    print("Accuracy - ", current_accuracy)
    print("Precision - ", current_precision)

    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)

# %%
performace_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores}).sort_values('Precision',ascending=false)

# %%
performace_df
